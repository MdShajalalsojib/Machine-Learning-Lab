# %% [markdown]
# <a href="https://colab.research.google.com/github/MdShajalalsojib/Machine-Learning-Lab/blob/main/text3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
so = pd.read_csv('StudentPerformanceFactors.csv')

# %%
so.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
so.shape
# Out:
# (6607, 20)

# %%
so.tail(5)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 6602                         No            7               76
# 6603                         No            8               81
# 6604                        Yes            6               65
# 6605                        Yes            6               91
# 6606                        Yes            9               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 6602           Medium             Yes                  1          High
# ...

# %%
so.sample(5)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 4208             15          82               Medium              Medium
# 2512             23          92                 High              Medium
# 1419             23          81                 High                 Low
# 2114             24          92                 High                High
# 4374             26          90               Medium              Medium
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 4208                        Yes           10               75
# 2512                        Yes            4               93
# 1419                        Yes           10               94
# 2114                         No            7               85
# 4374                        Yes            8               98
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 4208           Medium             Yes                  1          High
# ...

# %%
len (so.columns)
# Out:
# 20

# %%
len(so)
# Out:
# 6607

# %%
so[['Attendance']].isnull()
# Out:
#       Attendance
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 6602       False
# 6603       False
# 6604       False
# 6605       False
# 6606       False
#
# [6607 rows x 1 columns]

# %%
so[['Attendance']].sum()
# Out:
# Attendance    528411
# dtype: int64

# %%
so[['Attendance']].fillna(so['Attendance'].mean())
# Out:
#       Attendance
# 0             84
# 1             64
# 2             98
# 3             89
# 4             92
# ...          ...
# 6602          69
# 6603          76
# 6604          90
# 6605          86
# 6606          67
#
# [6607 rows x 1 columns]

# %%
so[['Attendance']].mean()
# Out:
# Attendance    79.977448
# dtype: float64

# %%
so[['Attendance']].max()
# Out:
# Attendance    100
# dtype: int64

# %%
so[['Attendance']].min()
# Out:
# Attendance    60
# dtype: int64

# %%
so[['Attendance']].mode()
# Out:
#    Attendance
# 0          67

# %%
axis = 1

# %%
axis = 0

# %%
so.drop('Attendance', axis=1)
# Out:
#       Hours_Studied Parental_Involvement Access_to_Resources  \
# 0                23                  Low                High
# 1                19                  Low              Medium
# 2                24               Medium              Medium
# 3                29                  Low              Medium
# 4                19               Medium              Medium
# ...             ...                  ...                 ...
# 6602             25                 High              Medium
# 6603             23                 High              Medium
# 6604             20               Medium                 Low
# 6605             10                 High                High
# 6606             15               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                            No            7               73
# 1                            No            8               59
# ...

# %%
so.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...
