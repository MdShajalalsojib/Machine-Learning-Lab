# %% [markdown]
# <a href="https://colab.research.google.com/github/MdShajalalsojib/Machine-Learning-Lab/blob/main/Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# install sklearn
# **!pip install scikit-learn**

# %% [markdown]
# **libraries**

# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %%
# sklearn dataset load
data = load_digits()

# %%
# X = features/ input and y = target/ output
X = data.data
y = data.target

# %%
# features/ input preview
X
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
# target/ output preview
y
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
# split
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.8,random_state=81)

# %%
# model
model = LogisticRegression(random_state=81,max_iter=3000)

# %%
# train
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=3000, random_state=81)

# %%
# prediction
y_predicted = model.predict(X_test)

# %%
# accuray
model.score(X_test,y_test)
# Out:
# 0.9555555555555556

# %%
1
# Out:
# 1

# %%
# reshape for plotting
X[81].reshape(8,8)
# Out:
# array([[ 0.,  0.,  3., 14., 16., 14.,  0.,  0.],
#        [ 0.,  0., 13., 13., 13., 16.,  2.,  0.],
#        [ 0.,  0.,  1.,  0.,  9., 15.,  0.,  0.],
#        [ 0.,  0.,  9., 12., 15., 16., 10.,  0.],
#        [ 0.,  4., 16., 16., 16., 11.,  3.,  0.],
#        [ 0.,  0.,  4.,  9., 14.,  2.,  0.,  0.],
#        [ 0.,  0.,  2., 15.,  9.,  0.,  0.,  0.],
#        [ 0.,  0.,  4., 13.,  1.,  0.,  0.,  0.]])

# %%
# image show
plt.imshow(X[81].reshape(8,8),cmap='gray')

# %%
# target
y[81]
# Out:
# np.int64(7)

# %%
# model predict
model.predict(X[[81]])
# Out:
# array([7])

# %%
import joblib

# %%
joblib.dump(model, 'logistic_regression.joblib')
# Out:
# ['logistic_regression.joblib']

# %%
old_model = joblib.load('logistic_regression.joblib')

# %%
old_model.predict(X_train[[100]])
# Out:
# array([1])

# %%
1
# Out:
# 1
