# %% [markdown]
# <a href="https://colab.research.google.com/github/MdShajalalsojib/Machine-Learning-Lab/blob/main/KNN_%2B_Clf_Report_%2B_Confusion_Matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix, classification_report
import matplotlib.pyplot as plt

# %%
data = load_iris()

# %%
X = data.data
y = data.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=81)

# %%
X = (X-X.min())/(X.max()-X.min())

# %%
X[:5]
# Out:
# array([[0.64102564, 0.43589744, 0.16666667, 0.01282051],
#        [0.61538462, 0.37179487, 0.16666667, 0.01282051],
#        [0.58974359, 0.3974359 , 0.15384615, 0.01282051],
#        [0.57692308, 0.38461538, 0.17948718, 0.01282051],
#        [0.62820513, 0.44871795, 0.16666667, 0.01282051]])

# %%
model = KNeighborsClassifier(n_neighbors=5)

# %%
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
# data.target_names

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
#cm

# %%
ConfusionMatrixDisplay(cm,display_labels=data.target_names).plot(cmap='Reds')

# %%
report = classification_report(y_test,y_pred,target_names=data.target_names)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        13
#   versicolor       1.00      1.00      1.00        10
#    virginica       1.00      1.00      1.00         7
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
1
# Out:
# 1
