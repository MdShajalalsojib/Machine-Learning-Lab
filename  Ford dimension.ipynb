# %% [markdown]
# <a href="https://colab.research.google.com/github/MdShajalalsojib/Machine-Learning-Lab/blob/main/%20Ford%20dimension.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORT LIBRARY
import pandas as pd

# %%
#Empty df
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
student = ['Md.Shajalal','Md.Sakib','Md.Kacham','Md.Ikbal']

# %%
student
# Out:
# ['Md.Shajalal', 'Md.Sakib', 'Md.Kacham', 'Md.Ikbal']

# %%
df = pd.DataFrame(student)
df
# Out:
#              0
# 0  Md.Shajalal
# 1     Md.Sakib
# 2    Md.Kacham
# 3     Md.Ikbal

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(student)
# Out:
# list

# %%
row, col = df.shape

# %%
row
# Out:
# 4

# %%
col
# Out:
# 1

# %%
df = pd.DataFrame(student, columns=['student_in_Name'])
df
# Out:
#   student_in_Name
# 0     Md.Shajalal
# 1        Md.Sakib
# 2       Md.Kacham
# 3        Md.Ikbal

# %%
df = pd.DataFrame(student, columns=['student_in_Name'])
df
# Out:
#   student_in_Name
# 0     Md.Shajalal
# 1        Md.Sakib
# 2       Md.Kacham
# 3        Md.Ikbal

# %%
df = pd.DataFrame(student, columns=['student_in_Name'], index = ['A','B','C','D'])
df
# Out:
#   student_in_Name
# A     Md.Shajalal
# B        Md.Sakib
# C       Md.Kacham
# D        Md.Ikbal

# %%
student2 = ['101','102','103','104']
df2 = pd.DataFrame(zip(student,student2), columns=['student_in_Name','student_ID'])

# %%
student4 = ['Md. Abdul Kasem','Md. Lokman','Md. Solman','Md. Koim']
df4 = pd.DataFrame(zip(student,student2,student4), columns=['student_in_Name','student_ID', 'student_Father_Name'])

# %%
df4
# Out:
#   student_in_Name student_ID student_Father_Name
# 0     Md.Shajalal        101     Md. Abdul Kasem
# 1        Md.Sakib        102          Md. Lokman
# 2       Md.Kacham        103          Md. Solman
# 3        Md.Ikbal        104            Md. Koim

# %%
student3 = ['Bangla','Software','Mathematics','Chemistry']
df3 = pd.DataFrame(zip(student,student2,student3,student4), columns=['student_in_Name','student_ID', 'Subject' ,'student_Father_Name' ])

# %%
df3
# Out:
#   student_in_Name student_ID      Subject student_Father_Name
# 0     Md.Shajalal        101       Bangla     Md. Abdul Kasem
# 1        Md.Sakib        102     Software          Md. Lokman
# 2       Md.Kacham        103  Mathematics          Md. Solman
# 3        Md.Ikbal        104    Chemistry            Md. Koim

# %%
df4
# Out:
#   student_in_Name student_ID student_Father_Name
# 0     Md.Shajalal        101     Md. Abdul Kasem
# 1        Md.Sakib        102          Md. Lokman
# 2       Md.Kacham        103          Md. Solman
# 3        Md.Ikbal        104            Md. Koim

# %%
df3
# Out:
#   student_in_Name student_ID          Subject student_Father_Name
# 0     Md.Shajalal        101  Md. Abdul Kasem              Bangla
# 1        Md.Sakib        102       Md. Lokman            Software
# 2       Md.Kacham        103       Md. Solman         Mathematics
# 3        Md.Ikbal        104         Md. Koim           Chemistry

# %%
df2
# Out:
#   student_in_Name student_ID
# 0     Md.Shajalal        101
# 1        Md.Sakib        102
# 2       Md.Kacham        103
# 3        Md.Ikbal        104

# %%
df3
# Out:
#   student_in_Name student_ID          Subject student_Father_Name
# 0     Md.Shajalal        101  Md. Abdul Kasem     Md. Abdul Kasem
# 1        Md.Sakib        102       Md. Lokman          Md. Lokman
# 2       Md.Kacham        103       Md. Solman          Md. Solman
# 3        Md.Ikbal        104         Md. Koim            Md. Koim

# %%
student
# Out:
# {'Md.Ikbal', 'Md.Kacham', 'Md.Sakib', 'Md.Shajalal'}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %%
stud = [['Md.shjalal', '101','English','A+'],['Md.sojib', '102','Bangla','A-'],['Md.sakib', '103','English','A'],['Md.Nazmul', '104','Softwar','A-'],['Md.Ashraful', '105','Maths','A']]

# %%
stud
# Out:
# [['Md.shjalal', '101', 'English', 'A+'],
#  ['Md.sojib', '102', 'Bangla', 'A-'],
#  ['Md.sakib', '103', 'English', 'A']]

# %%
so = pd.DataFrame(stud, columns=['studentName','studentID','Subject','CGPA'])

# %%
so
# Out:
#   studentName studentID  Subject CGPA
# 0  Md.shjalal       101  English   A+
# 1    Md.sojib       102   Bangla   A-
# 2    Md.sakib       103  English    A

# %%
so
# Out:
#   studentName studentID  Subject CGPA
# 0  Md.shjalal       101  English   A+
# 1    Md.sojib       102   Bangla   A-
# 2    Md.sakib       103  English    A

# %%
soj = pd.DataFrame(stud, columns=['studentName','studentID','Subject','CGPA'])

# %%
soj
# Out:
#    studentName studentID  Subject CGPA
# 0   Md.shjalal       101  English   A+
# 1     Md.sojib       102   Bangla   A-
# 2     Md.sakib       103  English    A
# 3    Md.Nazmul       104  Softwar   A-
# 4  Md.Ashraful       105    Maths    A
