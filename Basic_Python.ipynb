# %% [markdown]
# <a href="https://colab.research.google.com/github/MdShajalalsojib/Machine-Learning-Lab/blob/main/Basic_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World!')
# Out:
# Hello World!

# %%
print('Hello, "I am sojib"')
# Out:
# Hello, "I am sojib"

# %%
first_name = 'Machime Learning'
last_name = 'Lab'

full_name = first_name + " " + last_name
print(full_name)

full_name = full_name*3
print(full_name)

print(first_name, last_name)
# Out:
# Machime Learning Lab
# Machime Learning LabMachime Learning LabMachime Learning Lab
# Machime Learning Lab

# %%
m = 1
n = 2
# 12
m = str(m)
n = str(n)

print(m+n)

m = ''
print(bool(m))
print(type(m))
# Out:
# 12
# False
# <class 'str'>

# %%
n = int(input())
m = int(input())
print('sum this number = ',n+m)
# Out:
# 23
# 12
# sum this number =  35

# %%
n = int(input("Enter n: "))
m = int(input("Enter m: "))
print('sum number = ',n+m)
# Out:
# Enter n: 21
# Enter m: 56
# sum number =  77

# %%
x = 2
y = 3
print(y%x)
print(3**2)
print(pow(1000,3,32))
# Out:
# 1
# 9
# 0

# %%
x = 1
print(not x)
print(not 0)

x = 10
y = 5

print(x==10 and y==5)
print(x==10 or y==5)
# Out:
# False
# True
# True
# True

# %%
# (n+m)^2 == n^2+2nm+m^2

# %%
thisList = ['A',1,'C','A']
len(thisList)
# m = set(thisList)
# m
print(thisList[2])
print(thisList[-1])

#  0  1  2  3
# -4 -3 -2 -1

# start:end+1 => output: start:end
print(thisList[1:3])

# !!
print(thisList[-4:-2])
print(thisList[-2:-4])
print(thisList[:3])
print(thisList[::])
print(thisList[::-1])
# Out:
# C
# A
# [1, 'C']
# ['A', 1]
# []
# ['A', 1, 'C']
# ['A', 1, 'C', 'A']
# ['A', 'C', 1, 'A']

# %%
thisList
# Out:
# ['A', 1, 'C', 'A']

# %%
l = ['a','b','c']

l.append(['d','e'])
print(l)

l = ['a','c']
m = ['d','e']
l = l+m
print(l)
l.insert(1,'f')
print(l)

l = [1,2,3]
m = [4,5,6]
l.extend(m)
print(l)
l = [1,2,3,4,5,6]
l.remove(4)
print(l)
l.pop(1)
print(l)

del l
# Out:
# ['a', 'b', 'c', ['d', 'e']]
# ['a', 'c', 'd', 'e']
# ['a', 'f', 'c', 'd', 'e']
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 5, 6]
# [1, 3, 5, 6]

# %%
l = [1,2,5,0]
# l.sort()
ls = sorted(l)
print(ls)
# Out:
# [0, 1, 2, 5]

# %%
a = 1
b = 2

if a>b:
    print('A is greater')
elif a==b:
    print('Both are equal')
else:
    print('B is greater')
# Out:
# B is greater

# %%
l = [int(i) for i in input().split()]
print(l)
# Out:
# 2
# [2]

# %%
a, b = map(int,input().split())
print(a,b)
# Out:
# 23 5
# 23 5

# %%
l = [1,2,3]
for i in l:
    print(i)
# Out:
# 1
# 2
# 3

# %%
l = ['a','b','c']

print(' '.join(l))
# Out:
# a b c

# %%
l = [1,2,3]
for i in l:
    print(i,end=' ')
# Out:
# 1 2 3

# %%
l = [1,2,3,4,5,6,7,8,9,0]
# range(start,end+1,increment)
for i in range(0,len(l),2):
    print(l[i])
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
l = ['asdfsrgt','bert','crtert']
for i in l:
    print(i)
# Out:
# asdfsrgt
# bert
# crtert

# %%
i = 0
while i<5:
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
m = 2
n = 3
print(f'value {m} {n}')
print('value '+str(m)+' '+str(n))

round(3.1434243235,2)
# Out:
# value 2 3
# value 2 3
# 3.14

# %%
def myfun(n=0):
    return 2*n
myfun()
# Out:
# 0

# %%
try:
    print(2/0)
except:
    print('hoiche')
# Out:
# hoiche

# %%
def facto(n):
    facto=1
    for i in range(1,n+1):
        facto*=i
    return facto

facto(5)
# Out:
# 120

# %%
n = int(input())
for i in range(2,n):
    if n%i==0:
        print('not a prime')
        break
# Out:
# 300
# not a prime

# %%
m = {
    # 'key': 'value',
    'lab 1': 'ml basic',
    'lab 2': 'ml mid',
    'lab 3': 'ml adv',
}

# %%
# 1 2 3 1 4 5, a, a

l = [1,2,3,1,4,6,'a','a']
m = {}
for i in l:
    if i not in m:
        m[i]=0
    m[i]+=1

print(m.keys(), m.values())
# Out:
# dict_keys([1, 2, 3, 4, 6, 'a']) dict_values([2, 1, 1, 1, 1, 2])
